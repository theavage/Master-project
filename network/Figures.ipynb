# %%
import numpy as np
from matplotlib import pyplot as plt
import torch

# %%
loss = torch.load("/Users/theavage/Documents/Master/Master-project/network/models/loss_9180_2-15_100_noise_5.pt")

# %%
plt.figure()
plt.plot(loss)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training loss curve for 100 epocs')
# Out:
# Text(0.5, 1.0, 'Training loss curve for 100 epocs')
